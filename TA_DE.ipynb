# %% [markdown]
# <a href="https://colab.research.google.com/github/albanisyahrill/tugas-akhir-data-engineering/blob/main/TA_DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

pd.options.display.max_colwidth = 200 #max display lebar dari column nya

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Contents
#
# *   Read the dataset (corpus)
# *   Data Cleaning

# %% [markdown]
# # Read the Dataset
# Dataset link : https://www.kaggle.com/c/medical-notes/data. /- https://www.mtsamples.com/

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c240c7b3-7882-4501-a259-190d2d2e1c06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c240c7b3-7882-4501-a259-190d2d2e1c06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.StringIO(uploaded['deaths-and-new-cases-of-hiv.csv'].decode('utf-8')))
# io.StringIO, ngubah semua character yang ada di filenya menjadi string jadi data ini text-only data
# decode('utf-8') ini buat decoder kode universal untuk internasionalisasi dan mampu mengodekan seluruh set karakter Unicode
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)  \
# 0                                                         34
# 1                                                         41
# 2                                                         48
# 3                                                         56
# 4                                                         63
# ...                                                      ...
# 6835                                                   29162
# 6836                                                   27141
# ...

# %%
df.columns #Check kolom-kolom yg terdapat didalam data kita
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)',
#        'Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)',
#        'Prevalence - HIV/AIDS - Sex: Both - Age: All Ages (Number)'],
#       dtype='object')

# %%
df.head(5) #Check head data 5 teratas
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)  \
# 0                                                      34
# 1                                                      41
# 2                                                      48
# 3                                                      56
# 4                                                      63
#
#   Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)  \
# 0                                                      88.0
# 1                                                     104.0
# 2                                                     120.0
# 3                                                     127.0
# 4                                                     133.0
#
#    Prevalence - HIV/AIDS - Sex: Both - Age: All Ages (Number)
# ...

# %%
df.shape # Check total row + column
# Out:
# (6840, 6)

# %%
# Menghapus kolom yang tidak diperlukan
data_cleaned = df.drop(['Code', 'Prevalence - HIV/AIDS - Sex: Both - Age: All Ages (Number)'], axis=1)
data_cleaned.columns
# Out:
# Index(['Entity', 'Year',
#        'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)',
#        'Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)'],
#       dtype='object')

# %%
#Check apakah ada nilai yg kosong
#Jika outputnya true artinya mengandung nilai yang kosong, sebaliknya jika outputnya false artinya semua kolom terisi
data_cleaned.isnull().any()
# Out:
# Entity                                                       False
# Year                                                         False
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)       False
# Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)    False
# dtype: bool

# %%
#Mendapaktan jumlah nilai yg kosong dalam setiap kolom
data_cleaned.isnull().sum()
# Out:
# Entity                                                       0
# Year                                                         0
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)       0
# Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)    0
# dtype: int64

# %%
# Mengisi data kualitatif kosong dengan nilai "Unknown"
data_cleaned['Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)'].fillna("Unknown", inplace=True)
data_cleaned.isnull().sum()
# Out:
# Entity                                                       0
# Year                                                         0
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)       0
# Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)    0
# dtype: int64

# %%
# Buat peta pemetaan untuk mengelompokkan negara berdasarkan nama negara
peta_pemetaan = {
    'Australia': 'Maju', 
    'Austria': 'Maju',
    'Belgium': 'Maju',
    'Canada': 'Maju',
    'Denmark': 'Maju',
    'Finland': 'Maju',
    'France': 'Maju',
    'Germany': 'Maju',
    'Iceland': 'Maju',
    'Ireland': 'Maju',
    'Israel': 'Maju',
    'Italy': 'Maju',
    'Japan': 'Maju',
    'Luxembourg': 'Maju',
    'Netherlands': 'Maju',
    'New Zealand': 'Maju',
    'Norway': 'Maju',
    'Singapore': 'Maju',
    'South Korea': 'Maju',
    'Spain': 'Maju',
    'Sweden': 'Maju',
    'Switzerland': 'Maju',
    'United Kingdom': 'Maju',
    'United States': 'Maju',
    'Antigua and Barbuda': 'Maju',
    'Bahamas': 'Maju',
    'Barbados': 'Maju',
    'England': 'Maju',
    'European Region (WHO)': 'Maju',
    'G20': 'Maju',
    'North America (WB)': 'Maju',
    'Northern Ireland': 'Maju',
    'OECD Countries': 'Maju',
    'Puerto Rico': 'Maju',
    'Scotland': 'Maju',
    'Wales': 'Maju',
    'Western Pacific Region (WHO)': 'Maju',
    'World': 'Maju',
    'World Bank High Income': 'Maju',
    'Albania': 'Berkembang',
    'Algeria': 'Berkembang',
    'Angola': 'Berkembang',
    'Argentina': 'Berkembang',
    'Armenia': 'Berkembang',
    'Azerbaijan': 'Berkembang',
    'Bahrain': 'Berkembang',
    'Belarus': 'Berkembang',
    'Belize': 'Berkembang',
    'Benin': 'Berkembang',
    'Bhutan': 'Berkembang',
    'Bolivia': 'Berkembang',
    'Bosnia and Herzegovina': 'Berkembang',
    'Botswana': 'Berkembang',
    'Brazil': 'Berkembang',
    'Brunei': 'Berkembang',
    'Bulgaria': 'Berkembang',
    'Burkina Faso': 'Berkembang',
    'Burundi': 'Berkembang',
    'Cambodia': 'Berkembang',
    'Cameroon': 'Berkembang',
    'Cape Verde': 'Berkembang',
    'Central African Republic': 'Berkembang',
    'Chad': 'Berkembang',
    'Chile': 'Berkembang',
    'China': 'Berkembang',
    'Colombia': 'Berkembang',
    'Comoros': 'Berkembang',
    'Congo': 'Berkembang',
    'Costa Rica': 'Berkembang',
    "Cote d'Ivoire": 'Berkembang',
    'Croatia': 'Berkembang',
    'Cuba': 'Berkembang',
    'Cyprus': 'Berkembang',
    'Czechia': 'Berkembang',
    'Democratic Republic of Congo': 'Berkembang',
    'Djibouti': 'Berkembang',
    'Dominica': 'Berkembang',
    'Dominican Republic': 'Berkembang',
    'Ecuador': 'Berkembang',
    'Egypt': 'Berkembang',
    'El Salvador': 'Berkembang',
    'Equatorial Guinea': 'Berkembang',
    'Eritrea': 'Berkembang',
    'Estonia': 'Berkembang',
    'Eswatini': 'Berkembang',
    'Ethiopia': 'Berkembang',
    'Fiji': 'Berkembang',
    'Gabon': 'Berkembang',
    'Gambia': 'Berkembang',
    'Georgia': 'Berkembang',
    'Ghana': 'Berkembang',
    'Greece': 'Berkembang',
    'Grenada': 'Berkembang',
    'Guatemala': 'Berkembang',
    'Guinea': 'Berkembang',
    'Guinea-Bissau': 'Berkembang',
    'Guyana': 'Berkembang',
    'Haiti': 'Berkembang',
    'Honduras': 'Berkembang',
    'Hungary': 'Berkembang',
    'India': 'Berkembang',
    'Indonesia': 'Berkembang',
    'Iran': 'Berkembang',
    'Iraq': 'Berkembang',
    'Jamaica': 'Berkembang',
    'Jordan': 'Berkembang',
    'Kazakhstan': 'Berkembang',
    'Kenya': 'Berkembang',
    'Kiribati': 'Berkembang',
    'Kuwait': 'Berkembang',
    'Kyrgyzstan': 'Berkembang',
    'Laos': 'Berkembang',
    'Latvia': 'Berkembang',
    'Lebanon': 'Berkembang',
    'Lesotho': 'Berkembang',
    'Liberia': 'Berkembang',
    'Libya': 'Berkembang',
    'Lithuania': 'Berkembang',
    'Madagascar': 'Berkembang',
    'Malawi': 'Berkembang',
    'Malaysia': 'Berkembang',
    'Maldives': 'Berkembang',
    'Mali': 'Berkembang',
    'Malta': 'Berkembang',
    'Marshall Islands': 'Berkembang',
    'Mauritania': 'Berkembang',
    'Mauritius': 'Berkembang',
    'Mexico': 'Berkembang',
    'Micronesia (country)': 'Berkembang',
    'Moldova': 'Berkembang',
    'Mongolia': 'Berkembang',
    'Montenegro': 'Berkembang',
    'Morocco': 'Berkembang',
    'Mozambique': 'Berkembang',
    'Myanmar': 'Berkembang',
    'Namibia': 'Berkembang',
    'Nepal': 'Berkembang',
    'Nicaragua': 'Berkembang',
    'Niger': 'Berkembang',
    'Nigeria': 'Berkembang',
    'North Korea': 'Berkembang',
    'Oman': 'Berkembang',
    'Pakistan': 'Berkembang',
    'Palau': 'Berkembang',
    'Palestine': 'Berkembang',
    'Panama': 'Berkembang',
    'Papua New Guinea': 'Berkembang',
    'Paraguay': 'Berkembang',
    'Peru': 'Berkembang',
    'Philippines': 'Berkembang',
    'Poland': 'Berkembang',
    'Portugal': 'Berkembang',
    'Qatar': 'Berkembang',
    'Romania': 'Berkembang',
    'Russia': 'Berkembang',
    'Rwanda': 'Berkembang',
    'Saint Kitts and Nevis': 'Berkembang',
    'Saint Lucia': 'Berkembang',
    'Saint Vincent and the Grenadines': 'Berkembang',
    'Samoa': 'Berkembang',
    'San Marino': 'Berkembang',
    'Sao Tome and Principe': 'Berkembang',
    'Saudi Arabia': 'Berkembang',
    'Senegal': 'Berkembang',
    'Serbia': 'Berkembang',
    'Seychelles': 'Berkembang',
    'Sierra Leone': 'Berkembang',
    'Slovakia': 'Berkembang',
    'Slovenia': 'Berkembang',
    'Solomon Islands': 'Berkembang',
    'Somalia': 'Berkembang',
    'South Africa': 'Berkembang',
    'South Sudan': 'Berkembang',
    'Sri Lanka': 'Berkembang',
    'Sudan': 'Berkembang',
    'Suriname': 'Berkembang',
    'Syria': 'Berkembang',
    'Taiwan': 'Berkembang',
    'Tajikistan': 'Berkembang',
    'Tanzania': 'Berkembang',
    'Thailand': 'Berkembang',
    'Timor': 'Berkembang',
    'Togo': 'Berkembang',
    'Tonga': 'Berkembang',
    'Trinidad and Tobago': 'Berkembang',
    'Tunisia': 'Berkembang',
    'Turkey': 'Berkembang',
    'Turkmenistan': 'Berkembang',
    'Tuvalu': 'Berkembang',
    'Uganda': 'Berkembang',
    'Ukraine': 'Berkembang',
    'United Arab Emirates': 'Berkembang',
    'Uruguay': 'Berkembang',
    'Uzbekistan': 'Berkembang',
    'Vanuatu': 'Berkembang',
    'Venezuela': 'Berkembang',
    'Vietnam': 'Berkembang',
    'Yemen': 'Berkembang',
    'Zambia': 'Berkembang',
    'Zimbabwe': 'Berkembang',
    'Bangladesh': 'Berkembang',
    'East Asia & Pacific (WB)': 'Berkembang',
    'Eastern Mediterranean Region (WHO)': 'Berkembang',
    'Europe & Central Asia (WB)': 'Berkembang',
    'Latin America & Caribbean (WB)': 'Berkembang',
    'Middle East & North Africa (WB)': 'Berkembang',
    'North Macedonia': 'Berkembang',
    'Region of the Americas (WHO)': 'Berkembang',
    'South Asia (WB)': 'Berkembang',
    'South-East Asia Region (WHO)': 'Berkembang',
    'Sub-Saharan Africa (WB)': 'Berkembang',
    'World Bank Lower Middle Income': 'Berkembang',
    'World Bank Upper Middle Income': 'Berkembang',
    'Afghanistan': 'Terbelakang',
    'African Region (WHO)': 'Terbelakang',
    'American Samoa': 'Terbelakang',
    'Andorra': 'Terbelakang',
    'Bermuda': 'Terbelakang',
    'Cook Islands': 'Terbelakang',
    'Greenland': 'Terbelakang',
    'Guam': 'Terbelakang',
    'Monaco': 'Terbelakang',
    'Nauru': 'Terbelakang',
    'Niue': 'Terbelakang',
    'Northern Mariana Islands': 'Terbelakang',
    'Tokelau': 'Terbelakang',
    'United States Virgin Islands': 'Terbelakang',
    'World Bank Low Income': 'Terbelakang',
}

# Buat kolom baru yaitu "Classification" dan terapkan pemetaan
data_cleaned['Classification'] = data_cleaned['Entity'].map(peta_pemetaan)

#Mengecek apakah ada kolom yg masih kosong
#Jika outputnya true artinya mengandung nilai yang kosong, sebaliknya jika outputnya false artinya semua kolom terisi
data_cleaned.isnull().any()
# Out:
# Entity                                                       False
# Year                                                         False
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)       False
# Incidence - HIV/AIDS - Sex: Both - Age: All Ages (Number)    False
# Classification                                               False
# dtype: bool

# %%
# Menampilkan data
data_cleaned
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 6835     Zimbabwe  2015
# 6836     Zimbabwe  2016
# 6837     Zimbabwe  2017
# 6838     Zimbabwe  2018
# 6839     Zimbabwe  2019
#
#       Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)  \
# 0                                                         34
# 1                                                         41
# 2                                                         48
# 3                                                         56
# 4                                                         63
# ...                                                      ...
# 6835                                                   29162
# 6836                                                   27141
# 6837                                                   24846
# ...

# %%
# Menyimpan dataset setelah proses data cleaning
data_cleaned.to_csv('data-hiv-cleaned.csv', index=False)
